# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 2E3D-90D7
#
#  Directory of C:\Users\LENOVO\Desktop\pandas
#
# 07/02/2024  06:40 PM    <DIR>          .
# 06/29/2024  10:01 PM    <DIR>          ..
# 07/02/2024  06:38 PM    <DIR>          .ipynb_checkpoints
# 06/29/2024  09:50 AM                48 11Tes2t.csv
# 06/29/2024  09:47 AM                45 5T2es2t.csv
# 06/29/2024  09:47 AM                45 aaa5T2es2t.csv
# 07/02/2024  06:38 PM            21,522 ACLBSL_2000-01-01_2021-12-31.csv
# 06/28/2024  10:36 PM            13,658 Dataframe_in_pandas.ipynb
# 06/28/2024  10:44 PM            12,820 insert_and_deletepandas.ipynb
# 07/01/2024  08:22 AM            23,835 missing_data.ipynb
# 07/01/2024  07:53 PM            10,937 modidying_missing_values.ipynb
# 07/02/2024  06:40 PM               617 modmissingvalues2.ipynb
# 07/01/2024  06:54 AM            99,385 pandas_function.ipynb
# 06/28/2024  01:55 PM             4,191 PANDAS1.ipynb
# ...

# %%
ph=pd.read_csv('ACLBSL_2000-01-01_2021-12-31.csv')

# %%
ph
# Out:
#      S.N.        Date  Total Transactions  Total Traded Shares  \
# 0       1  2021-12-29                  34                696.0
# 1       2  2021-12-28                  48               1322.0
# 2       3  2021-12-27                  45               1023.0
# 3       4  2021-12-26                  43               2051.0
# 4       5  2021-12-23                  41               1153.0
# ..    ...         ...                 ...                  ...
# 352   353  2019-02-06                   1                 10.0
# 353   354  2019-02-05                   1                 10.0
# 354   355  2019-01-31                   3                 30.0
# 355   356  2019-01-08                   1                 10.0
# 356   357  2019-01-07                   1                  2.0
#
#      Total Traded Amount  Max. Price  Min. Price  Close Price
# 0               842596.0      1227.0      1205.0       1227.0
# 1              1575896.8      1227.0      1180.1       1227.0
# ...

# %%
ph.replace(to_replace=1,value=22)
# Out:
#      S.N.        Date  Total Transactions  Total Traded Shares  \
# 0      22  2021-12-29                  34                696.0
# 1       2  2021-12-28                  48               1322.0
# 2       3  2021-12-27                  45               1023.0
# 3       4  2021-12-26                  43               2051.0
# 4       5  2021-12-23                  41               1153.0
# ..    ...         ...                 ...                  ...
# 352   353  2019-02-06                  22                 10.0
# 353   354  2019-02-05                  22                 10.0
# 354   355  2019-01-31                   3                 30.0
# 355   356  2019-01-08                  22                 10.0
# 356   357  2019-01-07                  22                  2.0
#
#      Total Traded Amount  Max. Price  Min. Price  Close Price
# 0               842596.0      1227.0      1205.0       1227.0
# 1              1575896.8      1227.0      1180.1       1227.0
# ...

# %%
ph.replace([34,48,45,43,41],22)
# Out:
#      S.N.        Date  Total Transactions  Total Traded Shares  \
# 0       1  2021-12-29                  22                696.0
# 1       2  2021-12-28                  22               1322.0
# 2       3  2021-12-27                  22               1023.0
# 3       4  2021-12-26                  22               2051.0
# 4       5  2021-12-23                  22               1153.0
# ..    ...         ...                 ...                  ...
# 352   353  2019-02-06                   1                 10.0
# 353   354  2019-02-05                   1                 10.0
# 354   355  2019-01-31                   3                 30.0
# 355   356  2019-01-08                   1                 10.0
# 356   357  2019-01-07                   1                  2.0
#
#      Total Traded Amount  Max. Price  Min. Price  Close Price
# 0               842596.0      1227.0      1205.0       1227.0
# 1              1575896.8      1227.0      1180.1       1227.0
# ...

# %%
ph.replace("A-Za-z",'python',regex=True)
# Out:
#      S.N.        Date  Total Transactions  Total Traded Shares  \
# 0       1  2021-12-29                  34                696.0
# 1       2  2021-12-28                  48               1322.0
# 2       3  2021-12-27                  45               1023.0
# 3       4  2021-12-26                  43               2051.0
# 4       5  2021-12-23                  41               1153.0
# ..    ...         ...                 ...                  ...
# 352   353  2019-02-06                   1                 10.0
# 353   354  2019-02-05                   1                 10.0
# 354   355  2019-01-31                   3                 30.0
# 355   356  2019-01-08                   1                 10.0
# 356   357  2019-01-07                   1                  2.0
#
#      Total Traded Amount  Max. Price  Min. Price  Close Price
# 0               842596.0      1227.0      1205.0       1227.0
# 1              1575896.8      1227.0      1180.1       1227.0
# ...
